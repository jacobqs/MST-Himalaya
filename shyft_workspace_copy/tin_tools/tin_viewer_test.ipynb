# %%
import tin_simple_viewer as tinviewer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/tin_tools/tin_viewer_test.ipynb Cell 1 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bkeilhau.uio.no/uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/tin_tools/tin_viewer_test.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import tin_simple_viewer as tinviewer
#
# File ~/Master/code/MST-Himalaya/shyft_workspace_copy/tin_tools/tin_simple_viewer.py:2, in <module>
# ----> 2 from rasputin import tin_repository as tin
#       3 from pathlib import Path
#       4 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'rasputin'

# %%
view = tinviewer.TinSimpleViewer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/tin_tools/tin_viewer_test.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bkeilhau.uio.no/uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/tin_tools/tin_viewer_test.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> view = tinviewer.TinSimpleViewer()
#
# NameError: name 'tinviewer' is not defined

# %%
view.view_tins_terrain("tin_archive", "test_cid0","figs")
# Out:
# 2731
# 2731
# [(50, 'forest_type_2', 0, 160, 0), (90, 'forest_type_5', 40, 100, 0), (100, 'forest_type_6', 120, 130, 0), (110, 'shrub_type_1', 140, 160, 0), (150, 'vegetation_type_2', 255, 235, 175)]

# %%
view.view_tins_land_cover("tin_archive", "test_cid0","figs")
# Out:
# 2731
# 2731
# [(50, 'forest_type_2', 0, 160, 0), (90, 'forest_type_5', 40, 100, 0), (100, 'forest_type_6', 120, 130, 0), (110, 'shrub_type_1', 140, 160, 0), (150, 'vegetation_type_2', 255, 235, 175)]

# %%
view.calculate_statistics()
# Out:
# ======== Effective area statistics ============
# 507.7004866120781
# 504.5883429691201
# mean: 504.5883429691201
# median: 394.5129365972556
# variance: 155227.89868331037
# standard deviation: 393.98971900712127
# skew: 2.44984580855999
# kurtosis: 9.673420396411693
# ===== Normalised stats ======
# mean: 0.11203897049088943
# median: 0.08757042659076822
# variance: 0.0076701778640049815
# standard deviation: 0.0875795516316736
# skew: 2.4498458085599886
# kurtosis: 9.67342039641169
# ======== Effective height statistics ============
# mean: 189.5782031692224
# median: 188.97946527952627
# variance: 95.85906096643704
# standard deviation: 9.790764064486337
# skew: 0.13589162116239642
# kurtosis: -0.6164951141426429
# ===== Normalised stats ======
# mean: 0.48462642974581865
# median: 0.47039952836844545
# variance: 0.05412280887554312
# standard deviation: 0.23264309333299177
# skew: 0.13589162116239564
# kurtosis: -0.6164951141426442

# %%
import tin_simple_viewer_h5py as tinviewer

# %%
viewer_h5py = tinviewer.TinSimpleViewerH5PY()

# %%
tin_small_view = viewer_h5py.view_tins_terrain("/uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/shyft_workspace/shyft-data/budhi_gandaki/tin_archive", "narayani-cid-10-small","figs")
# Out:
# 911
# 911
# <HDF5 dataset "land_covers": shape (14,), type "|V116">

# %%
tin_small_stats = viewer_h5py.calculate_statistics()
# Out:
# ======== Effective area statistics ============
# 4659137.038669072
# 3980377.8583346135
# mean: 3980377.8583346135
# median: 3617074.87520005
# variance: 4792038598032.623
# standard deviation: 2189072.542889482
# skew: 1.155562734834274
# kurtosis: 2.1928844093984425
# ===== Normalised stats ======
# mean: 0.23250442926169107
# median: 0.21119245194416714
# variance: 0.016490349874662726
# standard deviation: 0.12841475723086784
# skew: 1.1555627348342743
# kurtosis: 2.1928844093984443
# ======== Effective height statistics ============
# mean: 4468.175388239311
# median: 4779.923352272002
# variance: 2315916.076257472
# standard deviation: 1521.8134170316255
# skew: -0.5955244057346941
# kurtosis: -0.2343656400168861
# ===== Normalised stats ======
# mean: 0.543317157996406
# median: 0.5849382451153694
# variance: 0.04128025817782364
# standard deviation: 0.20317543694507867
# skew: -0.5955244057346947
# kurtosis: -0.23436564001688565

# %%
tin_average_view = viewer_h5py.view_tins_terrain("/uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/shyft_workspace/shyft-data/budhi_gandaki/tin_archive", "narayani-cid-10-average","figs")
# Out:
# 1071
# 1071
# <HDF5 dataset "land_covers": shape (14,), type "|V116">

# %%
tin_average_stats = viewer_h5py.calculate_statistics()
# Out:
# ======== Effective area statistics ============
# 4586000.1579603255
# 3915981.89458161
# mean: 3915981.89458161
# median: 3536952.987945521
# variance: 4632261619875.751
# standard deviation: 2152268.946919913
# skew: 1.1541254689788316
# kurtosis: 2.186398916295568
# ===== Normalised stats ======
# mean: 0.22872685136512924
# median: 0.20649236435040996
# variance: 0.015940525782510196
# standard deviation: 0.126255795045258
# skew: 1.1541254689788314
# kurtosis: 2.186398916295568
# ======== Effective height statistics ============
# mean: 4455.500325488691
# median: 4763.736226011606
# variance: 2255354.553926155
# standard deviation: 1501.7837906723307
# skew: -0.6015363934815117
# kurtosis: -0.16719998431195826
# ===== Normalised stats ======
# mean: 0.5270964719688424
# median: 0.567144808375993
# variance: 0.038073021644688274
# standard deviation: 0.19512309357092583
# skew: -0.6015363934815109
# kurtosis: -0.1671999843119587

# %%
tin_bigger_view = viewer_h5py.view_tins_terrain("/uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/shyft_workspace/shyft-data/budhi_gandaki/tin_archive", "narayani-cid-10-bigger","figs")
# Out:
# 1382
# 1382
# <HDF5 dataset "land_covers": shape (14,), type "|V116">

# %%
tin_bigger_stats = viewer_h5py.calculate_statistics()
# Out:
# ======== Effective area statistics ============
# 4348371.011036584
# 3707625.6089311605
# mean: 3707625.6089311605
# median: 3315040.4545641025
# variance: 4415825316351.16
# standard deviation: 2101386.5223587877
# skew: 1.2144998530857505
# kurtosis: 2.396097889111628
# ===== Normalised stats ======
# mean: 0.21691462390896835
# median: 0.19389696458313566
# variance: 0.01517981418935119
# standard deviation: 0.12320638858984218
# skew: 1.2144998530857511
# kurtosis: 2.396097889111628
# ======== Effective height statistics ============
# mean: 4444.358643689513
# median: 4748.061503736157
# variance: 2164268.7450340735
# standard deviation: 1471.1453854171154
# skew: -0.586416972956793
# kurtosis: -0.09888568027315214
# ===== Normalised stats ======
# mean: 0.5237867435180964
# median: 0.5634010151142261
# variance: 0.036822796994741155
# standard deviation: 0.19189267050812847
# skew: -0.5864169729567944
# kurtosis: -0.09888568027314992

# %%
tin_largest_view = viewer_h5py.view_tins_terrain("/uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/shyft_workspace/shyft-data/budhi_gandaki/tin_archive", "narayani-cid-10-largest","figs")
# Out:
# 4681
# 4681
# <HDF5 dataset "land_covers": shape (14,), type "|V116">

# %%
tin_largest_stats = viewer_h5py.calculate_statistics()
# Out:
# ======== Effective area statistics ============
# 3045950.685220925
# 2584886.9490090115
# mean: 2584886.9490090115
# median: 1986929.4373513083
# variance: 4754349783237.882
# standard deviation: 2180447.1521313884
# skew: 1.3791545293286407
# kurtosis: 2.3752173194321156
# ===== Normalised stats ======
# mean: 0.15145541188557732
# median: 0.11641176732252227
# variance: 0.016329354288622214
# standard deviation: 0.1277863619038519
# skew: 1.3791545293286414
# kurtosis: 2.3752173194321182
# ======== Effective height statistics ============
# mean: 4419.3365168086975
# median: 4712.7219955554465
# variance: 1857989.2447801407
# standard deviation: 1363.080791728847
# skew: -0.694672716889521
# kurtosis: 0.11512426023069589
# ===== Normalised stats ======
# mean: 0.5115640923508067
# median: 0.5497625536278933
# variance: 0.03149616700446689
# standard deviation: 0.17747159492286896
# skew: -0.6946727168895224
# kurtosis: 0.11512426023069677

# %%
tin_small_landcover_view = viewer_h5py.view_tins_land_cover("/uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/shyft_workspace/shyft-data/budhi_gandaki/tin_archive", "narayani-cid-10-small","figs")
# Out:
# 911
# 911
# <HDF5 dataset "land_covers": shape (14,), type "|V116">

# %%
tin_small_landcover_stats = viewer_h5py.calculate_statistics()
# Out:
# ======== Effective area statistics ============
# 3182137.0136358426
# 2703041.5789403217
# mean: 2703041.5789403217
# median: 2144050.5481316093
# variance: 4983250780643.978
# standard deviation: 2232319.596438641
# skew: 1.3269039579679949
# kurtosis: 2.219310570116664
# ===== Normalised stats ======
# mean: 0.15837993206312864
# median: 0.12561994056592357
# variance: 0.01711554076081686
# standard deviation: 0.1308263763956522
# skew: 1.3269039579679949
# kurtosis: 2.2193105701166633
# ======== Effective height statistics ============
# mean: 4468.175388239311
# median: 4779.923352272002
# variance: 2315916.076257472
# standard deviation: 1521.8134170316255
# skew: -0.5955244057346941
# kurtosis: -0.2343656400168861
# ===== Normalised stats ======
# mean: 0.543317157996406
# median: 0.5849382451153694
# variance: 0.04128025817782364
# standard deviation: 0.20317543694507867
# skew: -0.5955244057346947
# kurtosis: -0.23436564001688565

# %%
tin_average_landcover_view = viewer_h5py.view_tins_land_cover("/uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/shyft_workspace/shyft-data/budhi_gandaki/tin_archive", "narayani-cid-10-average","figs")
# Out:
# 1071
# 1071
# <HDF5 dataset "land_covers": shape (14,), type "|V116">

# %%
tin_average_landcover_stats = viewer_h5py.calculate_statistics()
# Out:
# ======== Effective area statistics ============
# 3264117.939525084
# 2773453.1831684634
# mean: 2773453.1831684634
# median: 2270657.3380881157
# variance: 4952496805653.054
# standard deviation: 2225420.5907317954
# skew: 1.2746183920880947
# kurtosis: 2.0759916711384765
# ===== Normalised stats ======
# mean: 0.16250644470588307
# median: 0.13303980445258207
# variance: 0.01700991274093898
# standard deviation: 0.13042205619042732
# skew: 1.2746183920880956
# kurtosis: 2.0759916711384765
# ======== Effective height statistics ============
# mean: 4455.500325488691
# median: 4763.736226011606
# variance: 2255354.553926155
# standard deviation: 1501.7837906723307
# skew: -0.6015363934815117
# kurtosis: -0.16719998431195826
# ===== Normalised stats ======
# mean: 0.5270964719688424
# median: 0.567144808375993
# variance: 0.038073021644688274
# standard deviation: 0.19512309357092583
# skew: -0.6015363934815109
# kurtosis: -0.1671999843119587

# %%
tin_bigger_landcover_view = viewer_h5py.view_tins_land_cover("/uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/shyft_workspace/shyft-data/budhi_gandaki/tin_archive", "narayani-cid-10-bigger","figs")
# Out:
# 1382
# 1382
# <HDF5 dataset "land_covers": shape (14,), type "|V116">

# %%
tin_bigger_landcover_stats = viewer_h5py.calculate_statistics()
# Out:
# ======== Effective area statistics ============
# 3269679.3027736587
# 2776844.832028573
# mean: 2776844.832028573
# median: 2318036.2279461557
# variance: 4731619755890.008
# standard deviation: 2175228.667494525
# skew: 1.285259507915725
# kurtosis: 2.2111057519805675
# ===== Normalised stats ======
# mean: 0.16270521424187717
# median: 0.13581647159633012
# variance: 0.016251285428215245
# standard deviation: 0.127480529604388
# skew: 1.2852595079157247
# kurtosis: 2.2111057519805692
# ======== Effective height statistics ============
# mean: 4444.358643689513
# median: 4748.061503736157
# variance: 2164268.7450340735
# standard deviation: 1471.1453854171154
# skew: -0.586416972956793
# kurtosis: -0.09888568027315214
# ===== Normalised stats ======
# mean: 0.5237867435180964
# median: 0.5634010151142261
# variance: 0.036822796994741155
# standard deviation: 0.19189267050812847
# skew: -0.5864169729567944
# kurtosis: -0.09888568027314992

# %%
tin_largest_landcover_view = viewer_h5py.view_tins_land_cover("/uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/shyft_workspace/shyft-data/budhi_gandaki/tin_archive", "narayani-cid-10-largest","figs")
# Out:
# 4681
# 4681
# <HDF5 dataset "land_covers": shape (14,), type "|V116">

# %%
tin_largest_landcover_stats = viewer_h5py.calculate_statistics()
# Out:
# ======== Effective area statistics ============
# 2741534.802607034
# 2321774.334854739
# mean: 2321774.334854739
# median: 1556807.0627411609
# variance: 4359026380339.7705
# standard deviation: 2087828.14913962
# skew: 1.5586516807378572
# kurtosis: 3.0084999200459386
# ===== Normalised stats ======
# mean: 0.13603554550591263
# median: 0.09120419768656511
# variance: 0.014971571163942092
# standard deviation: 0.12235837185882334
# skew: 1.5586516807378568
# kurtosis: 3.0084999200459412
# ======== Effective height statistics ============
# mean: 4419.3365168086975
# median: 4712.7219955554465
# variance: 1857989.2447801407
# standard deviation: 1363.080791728847
# skew: -0.694672716889521
# kurtosis: 0.11512426023069589
# ===== Normalised stats ======
# mean: 0.5115640923508067
# median: 0.5497625536278933
# variance: 0.03149616700446689
# standard deviation: 0.17747159492286896
# skew: -0.6946727168895224
# kurtosis: 0.11512426023069677
