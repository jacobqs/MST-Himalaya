# %% [markdown]
# # Running a calibration with SHyFT
#
#
# ## This notebook is guiding through the simulation process of a catchment. The following steps are described:
# 1. **Loading required python modules and setting path to SHyFT installation**
# 2. **Configuration of a SHyFT calibration**
# 3. **Running a SHyFT calibration**
# 4. **Inspecting the calibration results**

# %% [markdown]
# ## 1. Loading required python modules and setting path to SHyFT installation
#
# Shyft requires a number of different modules to be loaded as part of the package. Below, we describe the required steps for loading the modules, and note that some steps are only required for the use of the jupyter notebook.

# %%
# Pure python modules and jupyter notebook functionality
# first you should import the third-party python modules which you'll use later on
# the first line enables that figures are shown inline, directly in the notebook
# %matplotlib inline
import os
import datetime as dt
from os import path
import sys
from matplotlib import pyplot as plt
import xarray as xr

# %% [markdown]
# ### The Shyft Environment
#
# This next step is highly specific on how and where you have installed Shyft. If you have followed the guidelines at github, and cloned the three shyft repositories: i) shyft, ii) shyft-data, and iii) shyft-doc, then you may need to tell jupyter notebooks where to find shyft. Uncomment the relevant lines below.
#
# If you have a 'system' shyft, or used `conda install -s sigbjorn shyft` to install shyft, then you probably will want to make sure you have set the SHYFT_DATA directory correctly, as otherwise, Shyft will assume the above structure and fail. __This has to be done _before_ `import shyft`__. In that case, uncomment the relevant lines below.
#
# **note**: it is most likely that you'll need to do one or the other.

# %%
from shyft.hydrology import shyftdata_dir

# shyftdata_dir should be set before starting jupyter notebook with shell command:
# $ export SHYFT_DATA = "path_to_shyft_data" 
# this export command can be added to ~/.bashrc profile

# %%
# try to auto-configure the path, -will work in all cases where doc and data
# are checked out at same level

shyft_data_path = os.path.abspath("../../../../shyft-data/")
if path.exists(shyft_data_path) and 'SHYFT_DATA' not in os.environ:
    os.environ['SHYFT_DATA']=shyft_data_path
    
# shyft should be available either by it's install in python
# or by PYTHONPATH set by user prior to starting notebook.
# This is equivalent to the two lines below
#  shyft_path=path.abspath('../../../shyft')
#  sys.path.insert(0,shyft_path)

# %%
print(shyft_data_path)
# Out:
# /uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/shyft_workspace/shyft-data

# %%
# importing the shyft modules needed for running a calibration
from shyft.hydrology.repository.default_state_repository import DefaultStateRepository
from shyft.hydrology.orchestration.configuration.yaml_configs import YAMLCalibConfig, YAMLSimConfig
from shyft.hydrology.orchestration.simulators.config_simulator import ConfigSimulator, ConfigCalibrator

# %%
#from ConfigCalibrator import *

# %% [markdown]
# ## 2. Configuration of a SHyFT calibration

# %%
# conduct a configured simulation first.
config_file_path = os.path.join(shyft_data_path, "budhi_gandaki/yaml_config/budhi_gandaki_simulation.yaml")

cfg_sim = YAMLSimConfig(config_file_path, "budhi_gandaki")
simulator = ConfigSimulator(cfg_sim) 
# run the model, and we'll just pull the `api.model` from the `simulator`
simulator.run()
state = simulator.region_model.state
# Out:
# Running simulation...

# %% [markdown]
# Now that we have the initial state, we'll run the calibration (this is not a strictly required step, but we use it later)

# %%
# # set up configuration using *.yaml configuration files
config_file_path = os.path.join(shyft_data_path,"budhi_gandaki/yaml_config/budhi_gandaki_calibration.yaml") # here is the *.yaml file
cfg_conf = YAMLCalibConfig(config_file_path, "budhi_gandaki")

# %%
# initialize an instance of the orchestration's ConfigCalcalibrator class, which has all the functionality needed
# to run a calibration using the above initiated configuration
calib = ConfigCalibrator(cfg_conf)
n_cells = calib.region_model.size()
state_repos = DefaultStateRepository(calib.region_model)  # Notice that this repository needs the real model
#                                                           so that it's able to generate a precise
#                                                           default state-with-id vector for this
#                                                           specific model
# Out:
# Creating TargetSpecificationVector...

# %% [markdown]
# ## 3. Running a SHyFT calibration

# %%
# once the calibrator is set up, all you need to do is running the calibration...
# the calibrated parameters are stored in a model.yaml. 
results = calib.calibrate(cfg_conf.sim_config.time_axis, state_repos.get_state(0), 
                          cfg_conf.optimization_method['name'],
                          cfg_conf.optimization_method['params'])
# Out:
# Calibrating...
# Storing calibrated params in: /uio/hume/student-u63/jacobqs/Master/code/MST-Himalaya/shyft_workspace_copy/shyft_workspace/shyft-data/budhi_gandaki/yaml_config/calibrated_model.yaml

# %% [markdown]
# ## 4. Inspecting the calibration results
# First the Nash-Suttcliffe-efficiency of the calibrated simulation is computed to see the quality of the calibration.
# Then the calibrated model parameters are accessed and printed out.

# %%
# Get NSE of calibrated run:
result_params = []
for i in range(results.size()):
    result_params.append(results.get(i))
print("Final NSE =", 1-calib.optimizer.calculate_goal_function(result_params))
# Out:
# Final NSE = 0.8943879976302259

# %%
# Check out the calibrated parameters.

diff = 1.0E-3
print("{0:30s} {1:10s}".format("PARAM-NAME", "CALIB-VALUE"))

for i in range(results.size()):
    print("{0:30s} {1:10f}".format(results.get_name(i), results.get(i)))
# Out:
# PARAM-NAME                     CALIB-VALUE
# kirchner.c1                     -5.816530
# kirchner.c2                     -0.163488
# kirchner.c3                     -0.110180
# ae.ae_scale_factor               1.500000
# gs.tx                            1.993781
# gs.wind_scale                    1.015917
# gs.max_water                     0.100000
# gs.wind_const                    1.000000
# gs.fast_albedo_decay_rate       12.286741
# gs.slow_albedo_decay_rate       26.656486
# gs.surface_magnitude            30.000000
# gs.max_albedo                    0.900000
# gs.min_albedo                    0.600000
# gs.snowfall_reset_depth          5.000000
# gs.snow_cv                       0.400000
# gs.glacier_albedo                0.400000
# p_corr.scale_factor              1.000000
# gs.snow_cv_forest_factor         0.000000
# gs.snow_cv_altitude_factor       0.000000
# pt.albedo                        0.200000
# pt.alpha                         1.260000
# gs.initial_bare_ground_fraction   0.040000
# gs.winter_end_day_of_year      100.000000
# gs.calculate_iso_pot_energy      0.000000
# gm.dtf                           5.000000
# routing.velocity                 0.000000
# routing.alpha                    0.900000
# routing.beta                     3.000000
# gs.n_winter_days               100.000000
# gm.direct_response               0.000000
# msp.reservoir_direct_response_fraction   1.000000

# %% [markdown]
# ### Plotting simulated and observed discharge
# We are now plotting the simulated and observed discharge timeseries over the course of the melt period.

# %%
# get the target vector and discharge statistics from the configured calibrator
target_obs = calib.tv[0]
disch_sim = calib.region_model.statistics.discharge(target_obs.catchment_indexes)
disch_obs = target_obs.ts.values


ts_timestamps_sim = [dt.datetime.utcfromtimestamp(p) for p in disch_sim.time_axis.time_points]
ts_timestamps_sim = ts_timestamps_sim[:-1]

ts_timestamps_obs = [dt.datetime.utcfromtimestamp(p) for p in target_obs.ts.time_axis.time_points]
ts_timestamps_obs = ts_timestamps_obs[:-1]

# %%
# plot up the results
fig, ax = plt.subplots(1, figsize=(15,10))
ax.plot(ts_timestamps_sim, disch_sim.values, lw=2, label = "sim")
ax.plot(ts_timestamps_obs, disch_obs, lw=2, ls='--', label = "obs")
ax.set_title("observed and simulated discharge")
ax.legend()
ax.set_ylabel("discharge [m3 s-1]")
# Out:
# Text(0, 0.5, 'discharge [m3 s-1]')

# %% [markdown]
# ## 5. Changing parameters on-the-fly
# Instead of changing model parameters in the yaml-configs, reload the configuration and re-run the model, we can also just change the parameters "on-the-fly", and rerun the model. This makes it easy to investigate the influence of certain model parameters on the simulation results.
#
# ### 5a. Snow or rain? The parameter gs.tx sets the threshold temperature at which precipitation is treated as snow fall.
#
# In the following we'll investigate the impact of manually manipulating this parameter.

# %%
parameters = calib.region_model.get_region_parameter() # fetching parameters from the simulator object
print(u"Calibrated rain/snow threshold temp: {} C".format(parameters.gs.tx)) # print current value of hs.tx
# Out:
# Calibrated rain/snow threshold temp: 1.9937805441140313 C

# %% [markdown]
# In the following, we first set the hs.tx parameter to a higher, and then to a lower value compared to the value the calibration results suggest. We re-run the simulation, respicetively, and plot the results.

# %%
calib.optimizer.calculate_goal_function(result_params) # reset the parameters to the values of the calibration
parameters.gs.tx = 4.0 # setting a higher value for tx
s_init = state.extract_state([])
# type(state)
# s0=state_repos.get_state(0)
# s0.state_vector
# state.apply_state(s0, [])
calib.run(state=s_init) # rerun the model, with new parameter
disch_sim_p_high = calib.region_model.statistics.discharge(target_obs.catchment_indexes) # fetch discharge ts
parameters.gs.tx = -4.0 # setting a higher value for tx

calib.run(state=s_init) # rerun the model, with new parameter

disch_sim_p_low = calib.region_model.statistics.discharge(target_obs.catchment_indexes) # fetch discharge ts
fig, ax = plt.subplots(1, figsize=(15,10))
ax.plot(ts_timestamps_sim, disch_sim.values, lw=2, label = "calib")
ax.plot(ts_timestamps_sim, disch_sim_p_high.values, lw=2, label = "high")
ax.plot(ts_timestamps_sim, disch_sim_p_low.values, lw=2, label = "low")
ax.plot(ts_timestamps_obs, disch_obs, lw=2, ls='--', label = "obs")
ax.set_title("investigating parameter gs.tx")
ax.legend()
ax.set_ylabel("discharge [m3 s-1]")
# Out:
# Running simulation...
# Running simulation...
# Text(0, 0.5, 'discharge [m3 s-1]')

# %%
s_init = state.extract_state([])

# reset the max water parameter
parameters.gs.max_water = 1.0 # setting a higher value for tx
calib.run(state=s_init) # rerun the model, with new parameter
disch_sim_p_high = calib.region_model.statistics.discharge(target_obs.catchment_indexes) # fetch discharge ts

parameters.gs.max_water = .001 # setting a lower value for tx
calib.run(state=s_init) # rerun the model, with new parameter
disch_sim_p_low = calib.region_model.statistics.discharge(target_obs.catchment_indexes) # fetch discharge ts

# plot the results
fig, ax = plt.subplots(1, figsize=(15,10))
ax.plot(ts_timestamps_sim, disch_sim.values, lw=2, label = "calib")
ax.plot(ts_timestamps_sim, disch_sim_p_high.values, lw=2, label = "high")
ax.plot(ts_timestamps_sim, disch_sim_p_low.values, lw=2, label = "low")
ax.plot(ts_timestamps_obs, disch_obs, lw=2, ls='--', label = "obs")
ax.set_title("investigating parameter gs.max_water")
ax.legend()
ax.set_ylabel("discharge [m3 s-1]")
# Out:
# Running simulation...
# Running simulation...
# Text(0, 0.5, 'discharge [m3 s-1]')

# %%
ts_timestamps_obs
# Out:
# [datetime.datetime(2000, 1, 1, 0, 0),
#  datetime.datetime(2000, 1, 1, 1, 0),
#  datetime.datetime(2000, 1, 1, 2, 0),
#  datetime.datetime(2000, 1, 1, 3, 0),
#  datetime.datetime(2000, 1, 1, 4, 0),
#  datetime.datetime(2000, 1, 1, 5, 0),
#  datetime.datetime(2000, 1, 1, 6, 0),
#  datetime.datetime(2000, 1, 1, 7, 0),
#  datetime.datetime(2000, 1, 1, 8, 0),
#  datetime.datetime(2000, 1, 1, 9, 0),
#  datetime.datetime(2000, 1, 1, 10, 0),
#  datetime.datetime(2000, 1, 1, 11, 0),
#  datetime.datetime(2000, 1, 1, 12, 0),
#  datetime.datetime(2000, 1, 1, 13, 0),
#  datetime.datetime(2000, 1, 1, 14, 0),
#  datetime.datetime(2000, 1, 1, 15, 0),
#  datetime.datetime(2000, 1, 1, 16, 0),
#  datetime.datetime(2000, 1, 1, 17, 0),
#  datetime.datetime(2000, 1, 1, 18, 0),
#  datetime.datetime(2000, 1, 1, 19, 0),
#  datetime.datetime(2000, 1, 1, 20, 0),
#  datetime.datetime(2000, 1, 1, 21, 0),
#  datetime.datetime(2000, 1, 1, 22, 0),
#  datetime.datetime(2000, 1, 1, 23, 0),
#  datetime.datetime(2000, 1, 2, 0, 0),
#  datetime.datetime(2000, 1, 2, 1, 0),
#  datetime.datetime(2000, 1, 2, 2, 0),
#  datetime.datetime(2000, 1, 2, 3, 0),
#  datetime.datetime(2000, 1, 2, 4, 0),
#  datetime.datetime(2000, 1, 2, 5, 0),
#  datetime.datetime(2000, 1, 2, 6, 0),
#  datetime.datetime(2000, 1, 2, 7, 0),
#  datetime.datetime(2000, 1, 2, 8, 0),
#  datetime.datetime(2000, 1, 2, 9, 0),
#  datetime.datetime(2000, 1, 2, 10, 0),
#  datetime.datetime(2000, 1, 2, 11, 0),
#  datetime.datetime(2000, 1, 2, 12, 0),
#  datetime.datetime(2000, 1, 2, 13, 0),
#  datetime.datetime(2000, 1, 2, 14, 0),
#  datetime.datetime(2000, 1, 2, 15, 0),
#  datetime.datetime(2000, 1, 2, 16, 0),
#  datetime.datetime(2000, 1, 2, 17, 0),
#  datetime.datetime(2000, 1, 2, 18, 0),
#  datetime.datetime(2000, 1, 2, 19, 0),
#  datetime.datetime(2000, 1, 2, 20, 0),
#  datetime.datetime(2000, 1, 2, 21, 0),
#  datetime.datetime(2000, 1, 2, 22, 0),
#  datetime.datetime(2000, 1, 2, 23, 0),
#  datetime.datetime(2000, 1, 3, 0, 0),
#  datetime.datetime(2000, 1, 3, 1, 0),
#  datetime.datetime(2000, 1, 3, 2, 0),
#  datetime.datetime(2000, 1, 3, 3, 0),
#  datetime.datetime(2000, 1, 3, 4, 0),
#  datetime.datetime(2000, 1, 3, 5, 0),
#  datetime.datetime(2000, 1, 3, 6, 0),
#  datetime.datetime(2000, 1, 3, 7, 0),
#  datetime.datetime(2000, 1, 3, 8, 0),
#  datetime.datetime(2000, 1, 3, 9, 0),
#  datetime.datetime(2000, 1, 3, 10, 0),
#  datetime.datetime(2000, 1, 3, 11, 0),
#  datetime.datetime(2000, 1, 3, 12, 0),
#  datetime.datetime(2000, 1, 3, 13, 0),
#  datetime.datetime(2000, 1, 3, 14, 0),
#  datetime.datetime(2000, 1, 3, 15, 0),
#  datetime.datetime(2000, 1, 3, 16, 0),
#  datetime.datetime(2000, 1, 3, 17, 0),
#  datetime.datetime(2000, 1, 3, 18, 0),
#  datetime.datetime(2000, 1, 3, 19, 0),
#  datetime.datetime(2000, 1, 3, 20, 0),
#  datetime.datetime(2000, 1, 3, 21, 0),
#  datetime.datetime(2000, 1, 3, 22, 0),
#  datetime.datetime(2000, 1, 3, 23, 0),
#  datetime.datetime(2000, 1, 4, 0, 0),
#  datetime.datetime(2000, 1, 4, 1, 0),
#  datetime.datetime(2000, 1, 4, 2, 0),
#  datetime.datetime(2000, 1, 4, 3, 0),
#  datetime.datetime(2000, 1, 4, 4, 0),
#  datetime.datetime(2000, 1, 4, 5, 0),
#  datetime.datetime(2000, 1, 4, 6, 0),
#  datetime.datetime(2000, 1, 4, 7, 0),
#  datetime.datetime(2000, 1, 4, 8, 0),
#  datetime.datetime(2000, 1, 4, 9, 0),
#  datetime.datetime(2000, 1, 4, 10, 0),
#  datetime.datetime(2000, 1, 4, 11, 0),
#  datetime.datetime(2000, 1, 4, 12, 0),
#  datetime.datetime(2000, 1, 4, 13, 0),
#  datetime.datetime(2000, 1, 4, 14, 0),
#  datetime.datetime(2000, 1, 4, 15, 0),
#  datetime.datetime(2000, 1, 4, 16, 0),
#  datetime.datetime(2000, 1, 4, 17, 0),
#  datetime.datetime(2000, 1, 4, 18, 0),
#  datetime.datetime(2000, 1, 4, 19, 0),
#  datetime.datetime(2000, 1, 4, 20, 0),
#  datetime.datetime(2000, 1, 4, 21, 0),
#  datetime.datetime(2000, 1, 4, 22, 0),
#  datetime.datetime(2000, 1, 4, 23, 0),
#  datetime.datetime(2000, 1, 5, 0, 0),
#  datetime.datetime(2000, 1, 5, 1, 0),
#  datetime.datetime(2000, 1, 5, 2, 0),
#  datetime.datetime(2000, 1, 5, 3, 0),
#  datetime.datetime(2000, 1, 5, 4, 0),
#  datetime.datetime(2000, 1, 5, 5, 0),
#  datetime.datetime(2000, 1, 5, 6, 0),
#  datetime.datetime(2000, 1, 5, 7, 0),
#  datetime.datetime(2000, 1, 5, 8, 0),
#  datetime.datetime(2000, 1, 5, 9, 0),
#  datetime.datetime(2000, 1, 5, 10, 0),
#  datetime.datetime(2000, 1, 5, 11, 0),
#  datetime.datetime(2000, 1, 5, 12, 0),
#  datetime.datetime(2000, 1, 5, 13, 0),
#  datetime.datetime(2000, 1, 5, 14, 0),
#  datetime.datetime(2000, 1, 5, 15, 0),
#  datetime.datetime(2000, 1, 5, 16, 0),
#  datetime.datetime(2000, 1, 5, 17, 0),
#  datetime.datetime(2000, 1, 5, 18, 0),
#  datetime.datetime(2000, 1, 5, 19, 0),
#  datetime.datetime(2000, 1, 5, 20, 0),
#  datetime.datetime(2000, 1, 5, 21, 0),
#  datetime.datetime(2000, 1, 5, 22, 0),
#  datetime.datetime(2000, 1, 5, 23, 0),
#  datetime.datetime(2000, 1, 6, 0, 0),
#  datetime.datetime(2000, 1, 6, 1, 0),
#  datetime.datetime(2000, 1, 6, 2, 0),
#  datetime.datetime(2000, 1, 6, 3, 0),
#  datetime.datetime(2000, 1, 6, 4, 0),
#  datetime.datetime(2000, 1, 6, 5, 0),
#  datetime.datetime(2000, 1, 6, 6, 0),
#  datetime.datetime(2000, 1, 6, 7, 0),
#  datetime.datetime(2000, 1, 6, 8, 0),
#  datetime.datetime(2000, 1, 6, 9, 0),
#  datetime.datetime(2000, 1, 6, 10, 0),
#  datetime.datetime(2000, 1, 6, 11, 0),
#  datetime.datetime(2000, 1, 6, 12, 0),
#  datetime.datetime(2000, 1, 6, 13, 0),
#  datetime.datetime(2000, 1, 6, 14, 0),
#  datetime.datetime(2000, 1, 6, 15, 0),
#  datetime.datetime(2000, 1, 6, 16, 0),
#  datetime.datetime(2000, 1, 6, 17, 0),
#  datetime.datetime(2000, 1, 6, 18, 0),
#  datetime.datetime(2000, 1, 6, 19, 0),
#  datetime.datetime(2000, 1, 6, 20, 0),
#  datetime.datetime(2000, 1, 6, 21, 0),
#  datetime.datetime(2000, 1, 6, 22, 0),
#  datetime.datetime(2000, 1, 6, 23, 0),
#  datetime.datetime(2000, 1, 7, 0, 0),
#  datetime.datetime(2000, 1, 7, 1, 0),
#  datetime.datetime(2000, 1, 7, 2, 0),
#  datetime.datetime(2000, 1, 7, 3, 0),
#  datetime.datetime(2000, 1, 7, 4, 0),
#  datetime.datetime(2000, 1, 7, 5, 0),
#  datetime.datetime(2000, 1, 7, 6, 0),
#  datetime.datetime(2000, 1, 7, 7, 0),
#  datetime.datetime(2000, 1, 7, 8, 0),
#  datetime.datetime(2000, 1, 7, 9, 0),
#  datetime.datetime(2000, 1, 7, 10, 0),
#  datetime.datetime(2000, 1, 7, 11, 0),
#  datetime.datetime(2000, 1, 7, 12, 0),
#  datetime.datetime(2000, 1, 7, 13, 0),
#  datetime.datetime(2000, 1, 7, 14, 0),
#  datetime.datetime(2000, 1, 7, 15, 0),
#  datetime.datetime(2000, 1, 7, 16, 0),
#  datetime.datetime(2000, 1, 7, 17, 0),
#  datetime.datetime(2000, 1, 7, 18, 0),
#  datetime.datetime(2000, 1, 7, 19, 0),
#  datetime.datetime(2000, 1, 7, 20, 0),
#  datetime.datetime(2000, 1, 7, 21, 0),
#  datetime.datetime(2000, 1, 7, 22, 0),
#  datetime.datetime(2000, 1, 7, 23, 0),
#  datetime.datetime(2000, 1, 8, 0, 0),
#  datetime.datetime(2000, 1, 8, 1, 0),
#  datetime.datetime(2000, 1, 8, 2, 0),
#  datetime.datetime(2000, 1, 8, 3, 0),
#  datetime.datetime(2000, 1, 8, 4, 0),
#  datetime.datetime(2000, 1, 8, 5, 0),
#  datetime.datetime(2000, 1, 8, 6, 0),
#  datetime.datetime(2000, 1, 8, 7, 0),
#  datetime.datetime(2000, 1, 8, 8, 0),
#  datetime.datetime(2000, 1, 8, 9, 0),
#  datetime.datetime(2000, 1, 8, 10, 0),
#  datetime.datetime(2000, 1, 8, 11, 0),
#  datetime.datetime(2000, 1, 8, 12, 0),
#  datetime.datetime(2000, 1, 8, 13, 0),
#  datetime.datetime(2000, 1, 8, 14, 0),
#  datetime.datetime(2000, 1, 8, 15, 0),
#  datetime.datetime(2000, 1, 8, 16, 0),
#  datetime.datetime(2000, 1, 8, 17, 0),
#  datetime.datetime(2000, 1, 8, 18, 0),
#  datetime.datetime(2000, 1, 8, 19, 0),
#  datetime.datetime(2000, 1, 8, 20, 0),
#  datetime.datetime(2000, 1, 8, 21, 0),
#  datetime.datetime(2000, 1, 8, 22, 0),
#  datetime.datetime(2000, 1, 8, 23, 0),
#  datetime.datetime(2000, 1, 9, 0, 0),
#  datetime.datetime(2000, 1, 9, 1, 0),
#  datetime.datetime(2000, 1, 9, 2, 0),
#  datetime.datetime(2000, 1, 9, 3, 0),
#  datetime.datetime(2000, 1, 9, 4, 0),
#  datetime.datetime(2000, 1, 9, 5, 0),
#  datetime.datetime(2000, 1, 9, 6, 0),
#  datetime.datetime(2000, 1, 9, 7, 0),
#  datetime.datetime(2000, 1, 9, 8, 0),
#  datetime.datetime(2000, 1, 9, 9, 0),
#  datetime.datetime(2000, 1, 9, 10, 0),
#  datetime.datetime(2000, 1, 9, 11, 0),
#  datetime.datetime(2000, 1, 9, 12, 0),
#  datetime.datetime(2000, 1, 9, 13, 0),
#  datetime.datetime(2000, 1, 9, 14, 0),
#  datetime.datetime(2000, 1, 9, 15, 0),
#  datetime.datetime(2000, 1, 9, 16, 0),
#  datetime.datetime(2000, 1, 9, 17, 0),
#  datetime.datetime(2000, 1, 9, 18, 0),
#  datetime.datetime(2000, 1, 9, 19, 0),
#  datetime.datetime(2000, 1, 9, 20, 0),
#  datetime.datetime(2000, 1, 9, 21, 0),
#  datetime.datetime(2000, 1, 9, 22, 0),
#  datetime.datetime(2000, 1, 9, 23, 0),
#  datetime.datetime(2000, 1, 10, 0, 0),
#  datetime.datetime(2000, 1, 10, 1, 0),
#  datetime.datetime(2000, 1, 10, 2, 0),
#  datetime.datetime(2000, 1, 10, 3, 0),
#  datetime.datetime(2000, 1, 10, 4, 0),
#  datetime.datetime(2000, 1, 10, 5, 0),
#  datetime.datetime(2000, 1, 10, 6, 0),
#  datetime.datetime(2000, 1, 10, 7, 0),
#  datetime.datetime(2000, 1, 10, 8, 0),
#  datetime.datetime(2000, 1, 10, 9, 0),
#  datetime.datetime(2000, 1, 10, 10, 0),
#  datetime.datetime(2000, 1, 10, 11, 0),
#  datetime.datetime(2000, 1, 10, 12, 0),
#  datetime.datetime(2000, 1, 10, 13, 0),
#  datetime.datetime(2000, 1, 10, 14, 0),
#  datetime.datetime(2000, 1, 10, 15, 0),
#  datetime.datetime(2000, 1, 10, 16, 0),
#  datetime.datetime(2000, 1, 10, 17, 0),
#  datetime.datetime(2000, 1, 10, 18, 0),
#  datetime.datetime(2000, 1, 10, 19, 0),
#  datetime.datetime(2000, 1, 10, 20, 0),
#  datetime.datetime(2000, 1, 10, 21, 0),
#  datetime.datetime(2000, 1, 10, 22, 0),
#  datetime.datetime(2000, 1, 10, 23, 0),
#  datetime.datetime(2000, 1, 11, 0, 0),
#  datetime.datetime(2000, 1, 11, 1, 0),
#  datetime.datetime(2000, 1, 11, 2, 0),
#  datetime.datetime(2000, 1, 11, 3, 0),
#  datetime.datetime(2000, 1, 11, 4, 0),
#  datetime.datetime(2000, 1, 11, 5, 0),
#  datetime.datetime(2000, 1, 11, 6, 0),
#  datetime.datetime(2000, 1, 11, 7, 0),
#  datetime.datetime(2000, 1, 11, 8, 0),
#  datetime.datetime(2000, 1, 11, 9, 0),
#  datetime.datetime(2000, 1, 11, 10, 0),
#  datetime.datetime(2000, 1, 11, 11, 0),
#  datetime.datetime(2000, 1, 11, 12, 0),
#  datetime.datetime(2000, 1, 11, 13, 0),
#  datetime.datetime(2000, 1, 11, 14, 0),
#  datetime.datetime(2000, 1, 11, 15, 0),
#  datetime.datetime(2000, 1, 11, 16, 0),
#  datetime.datetime(2000, 1, 11, 17, 0),
#  datetime.datetime(2000, 1, 11, 18, 0),
#  datetime.datetime(2000, 1, 11, 19, 0),
#  datetime.datetime(2000, 1, 11, 20, 0),
#  datetime.datetime(2000, 1, 11, 21, 0),
#  datetime.datetime(2000, 1, 11, 22, 0),
#  datetime.datetime(2000, 1, 11, 23, 0),
#  datetime.datetime(2000, 1, 12, 0, 0),
#  datetime.datetime(2000, 1, 12, 1, 0),
#  datetime.datetime(2000, 1, 12, 2, 0),
#  datetime.datetime(2000, 1, 12, 3, 0),
#  datetime.datetime(2000, 1, 12, 4, 0),
#  datetime.datetime(2000, 1, 12, 5, 0),
#  datetime.datetime(2000, 1, 12, 6, 0),
#  datetime.datetime(2000, 1, 12, 7, 0),
#  datetime.datetime(2000, 1, 12, 8, 0),
#  datetime.datetime(2000, 1, 12, 9, 0),
#  datetime.datetime(2000, 1, 12, 10, 0),
#  datetime.datetime(2000, 1, 12, 11, 0),
#  datetime.datetime(2000, 1, 12, 12, 0),
#  datetime.datetime(2000, 1, 12, 13, 0),
#  datetime.datetime(2000, 1, 12, 14, 0),
#  datetime.datetime(2000, 1, 12, 15, 0),
#  datetime.datetime(2000, 1, 12, 16, 0),
#  datetime.datetime(2000, 1, 12, 17, 0),
#  datetime.datetime(2000, 1, 12, 18, 0),
#  datetime.datetime(2000, 1, 12, 19, 0),
#  datetime.datetime(2000, 1, 12, 20, 0),
#  datetime.datetime(2000, 1, 12, 21, 0),
#  datetime.datetime(2000, 1, 12, 22, 0),
#  datetime.datetime(2000, 1, 12, 23, 0),
#  datetime.datetime(2000, 1, 13, 0, 0),
#  datetime.datetime(2000, 1, 13, 1, 0),
#  datetime.datetime(2000, 1, 13, 2, 0),
#  datetime.datetime(2000, 1, 13, 3, 0),
#  datetime.datetime(2000, 1, 13, 4, 0),
#  datetime.datetime(2000, 1, 13, 5, 0),
#  datetime.datetime(2000, 1, 13, 6, 0),
#  datetime.datetime(2000, 1, 13, 7, 0),
#  datetime.datetime(2000, 1, 13, 8, 0),
#  datetime.datetime(2000, 1, 13, 9, 0),
#  datetime.datetime(2000, 1, 13, 10, 0),
#  datetime.datetime(2000, 1, 13, 11, 0),
#  datetime.datetime(2000, 1, 13, 12, 0),
#  datetime.datetime(2000, 1, 13, 13, 0),
#  datetime.datetime(2000, 1, 13, 14, 0),
#  datetime.datetime(2000, 1, 13, 15, 0),
#  datetime.datetime(2000, 1, 13, 16, 0),
#  datetime.datetime(2000, 1, 13, 17, 0),
#  datetime.datetime(2000, 1, 13, 18, 0),
#  datetime.datetime(2000, 1, 13, 19, 0),
#  datetime.datetime(2000, 1, 13, 20, 0),
#  datetime.datetime(2000, 1, 13, 21, 0),
#  datetime.datetime(2000, 1, 13, 22, 0),
#  datetime.datetime(2000, 1, 13, 23, 0),
#  datetime.datetime(2000, 1, 14, 0, 0),
#  datetime.datetime(2000, 1, 14, 1, 0),
#  datetime.datetime(2000, 1, 14, 2, 0),
#  datetime.datetime(2000, 1, 14, 3, 0),
#  datetime.datetime(2000, 1, 14, 4, 0),
#  datetime.datetime(2000, 1, 14, 5, 0),
#  datetime.datetime(2000, 1, 14, 6, 0),
#  datetime.datetime(2000, 1, 14, 7, 0),
#  datetime.datetime(2000, 1, 14, 8, 0),
#  datetime.datetime(2000, 1, 14, 9, 0),
#  datetime.datetime(2000, 1, 14, 10, 0),
#  datetime.datetime(2000, 1, 14, 11, 0),
#  datetime.datetime(2000, 1, 14, 12, 0),
#  datetime.datetime(2000, 1, 14, 13, 0),
#  datetime.datetime(2000, 1, 14, 14, 0),
#  datetime.datetime(2000, 1, 14, 15, 0),
#  datetime.datetime(2000, 1, 14, 16, 0),
#  datetime.datetime(2000, 1, 14, 17, 0),
#  datetime.datetime(2000, 1, 14, 18, 0),
#  datetime.datetime(2000, 1, 14, 19, 0),
#  datetime.datetime(2000, 1, 14, 20, 0),
#  datetime.datetime(2000, 1, 14, 21, 0),
#  datetime.datetime(2000, 1, 14, 22, 0),
#  datetime.datetime(2000, 1, 14, 23, 0),
#  datetime.datetime(2000, 1, 15, 0, 0),
#  datetime.datetime(2000, 1, 15, 1, 0),
#  datetime.datetime(2000, 1, 15, 2, 0),
#  datetime.datetime(2000, 1, 15, 3, 0),
#  datetime.datetime(2000, 1, 15, 4, 0),
#  datetime.datetime(2000, 1, 15, 5, 0),
#  datetime.datetime(2000, 1, 15, 6, 0),
#  datetime.datetime(2000, 1, 15, 7, 0),
#  datetime.datetime(2000, 1, 15, 8, 0),
#  datetime.datetime(2000, 1, 15, 9, 0),
#  datetime.datetime(2000, 1, 15, 10, 0),
#  datetime.datetime(2000, 1, 15, 11, 0),
#  datetime.datetime(2000, 1, 15, 12, 0),
#  datetime.datetime(2000, 1, 15, 13, 0),
#  datetime.datetime(2000, 1, 15, 14, 0),
#  datetime.datetime(2000, 1, 15, 15, 0),
#  datetime.datetime(2000, 1, 15, 16, 0),
#  datetime.datetime(2000, 1, 15, 17, 0),
#  datetime.datetime(2000, 1, 15, 18, 0),
#  datetime.datetime(2000, 1, 15, 19, 0),
#  datetime.datetime(2000, 1, 15, 20, 0),
#  datetime.datetime(2000, 1, 15, 21, 0),
#  datetime.datetime(2000, 1, 15, 22, 0),
#  datetime.datetime(2000, 1, 15, 23, 0),
#  datetime.datetime(2000, 1, 16, 0, 0),
#  datetime.datetime(2000, 1, 16, 1, 0),
#  datetime.datetime(2000, 1, 16, 2, 0),
#  datetime.datetime(2000, 1, 16, 3, 0),
#  datetime.datetime(2000, 1, 16, 4, 0),
#  datetime.datetime(2000, 1, 16, 5, 0),
#  datetime.datetime(2000, 1, 16, 6, 0),
#  datetime.datetime(2000, 1, 16, 7, 0),
#  datetime.datetime(2000, 1, 16, 8, 0),
#  datetime.datetime(2000, 1, 16, 9, 0),
#  datetime.datetime(2000, 1, 16, 10, 0),
#  datetime.datetime(2000, 1, 16, 11, 0),
#  datetime.datetime(2000, 1, 16, 12, 0),
#  datetime.datetime(2000, 1, 16, 13, 0),
#  datetime.datetime(2000, 1, 16, 14, 0),
#  datetime.datetime(2000, 1, 16, 15, 0),
#  datetime.datetime(2000, 1, 16, 16, 0),
#  datetime.datetime(2000, 1, 16, 17, 0),
#  datetime.datetime(2000, 1, 16, 18, 0),
#  datetime.datetime(2000, 1, 16, 19, 0),
#  datetime.datetime(2000, 1, 16, 20, 0),
#  datetime.datetime(2000, 1, 16, 21, 0),
#  datetime.datetime(2000, 1, 16, 22, 0),
#  datetime.datetime(2000, 1, 16, 23, 0),
#  datetime.datetime(2000, 1, 17, 0, 0),
#  datetime.datetime(2000, 1, 17, 1, 0),
#  datetime.datetime(2000, 1, 17, 2, 0),
#  datetime.datetime(2000, 1, 17, 3, 0),
#  datetime.datetime(2000, 1, 17, 4, 0),
#  datetime.datetime(2000, 1, 17, 5, 0),
#  datetime.datetime(2000, 1, 17, 6, 0),
#  datetime.datetime(2000, 1, 17, 7, 0),
#  datetime.datetime(2000, 1, 17, 8, 0),
#  datetime.datetime(2000, 1, 17, 9, 0),
#  datetime.datetime(2000, 1, 17, 10, 0),
#  datetime.datetime(2000, 1, 17, 11, 0),
#  datetime.datetime(2000, 1, 17, 12, 0),
#  datetime.datetime(2000, 1, 17, 13, 0),
#  datetime.datetime(2000, 1, 17, 14, 0),
#  datetime.datetime(2000, 1, 17, 15, 0),
#  datetime.datetime(2000, 1, 17, 16, 0),
#  datetime.datetime(2000, 1, 17, 17, 0),
#  datetime.datetime(2000, 1, 17, 18, 0),
#  datetime.datetime(2000, 1, 17, 19, 0),
#  datetime.datetime(2000, 1, 17, 20, 0),
#  datetime.datetime(2000, 1, 17, 21, 0),
#  datetime.datetime(2000, 1, 17, 22, 0),
#  datetime.datetime(2000, 1, 17, 23, 0),
#  datetime.datetime(2000, 1, 18, 0, 0),
#  datetime.datetime(2000, 1, 18, 1, 0),
#  datetime.datetime(2000, 1, 18, 2, 0),
#  datetime.datetime(2000, 1, 18, 3, 0),
#  datetime.datetime(2000, 1, 18, 4, 0),
#  datetime.datetime(2000, 1, 18, 5, 0),
#  datetime.datetime(2000, 1, 18, 6, 0),
#  datetime.datetime(2000, 1, 18, 7, 0),
#  datetime.datetime(2000, 1, 18, 8, 0),
#  datetime.datetime(2000, 1, 18, 9, 0),
#  datetime.datetime(2000, 1, 18, 10, 0),
#  datetime.datetime(2000, 1, 18, 11, 0),
#  datetime.datetime(2000, 1, 18, 12, 0),
#  datetime.datetime(2000, 1, 18, 13, 0),
#  datetime.datetime(2000, 1, 18, 14, 0),
#  datetime.datetime(2000, 1, 18, 15, 0),
#  datetime.datetime(2000, 1, 18, 16, 0),
#  datetime.datetime(2000, 1, 18, 17, 0),
#  datetime.datetime(2000, 1, 18, 18, 0),
#  datetime.datetime(2000, 1, 18, 19, 0),
#  datetime.datetime(2000, 1, 18, 20, 0),
#  datetime.datetime(2000, 1, 18, 21, 0),
#  datetime.datetime(2000, 1, 18, 22, 0),
#  datetime.datetime(2000, 1, 18, 23, 0),
#  datetime.datetime(2000, 1, 19, 0, 0),
#  datetime.datetime(2000, 1, 19, 1, 0),
#  datetime.datetime(2000, 1, 19, 2, 0),
#  datetime.datetime(2000, 1, 19, 3, 0),
#  datetime.datetime(2000, 1, 19, 4, 0),
#  datetime.datetime(2000, 1, 19, 5, 0),
#  datetime.datetime(2000, 1, 19, 6, 0),
#  datetime.datetime(2000, 1, 19, 7, 0),
#  datetime.datetime(2000, 1, 19, 8, 0),
#  datetime.datetime(2000, 1, 19, 9, 0),
#  datetime.datetime(2000, 1, 19, 10, 0),
#  datetime.datetime(2000, 1, 19, 11, 0),
#  datetime.datetime(2000, 1, 19, 12, 0),
#  datetime.datetime(2000, 1, 19, 13, 0),
#  datetime.datetime(2000, 1, 19, 14, 0),
#  datetime.datetime(2000, 1, 19, 15, 0),
#  datetime.datetime(2000, 1, 19, 16, 0),
#  datetime.datetime(2000, 1, 19, 17, 0),
#  datetime.datetime(2000, 1, 19, 18, 0),
#  datetime.datetime(2000, 1, 19, 19, 0),
#  datetime.datetime(2000, 1, 19, 20, 0),
#  datetime.datetime(2000, 1, 19, 21, 0),
#  datetime.datetime(2000, 1, 19, 22, 0),
#  datetime.datetime(2000, 1, 19, 23, 0),
#  datetime.datetime(2000, 1, 20, 0, 0),
#  datetime.datetime(2000, 1, 20, 1, 0),
#  datetime.datetime(2000, 1, 20, 2, 0),
#  datetime.datetime(2000, 1, 20, 3, 0),
#  datetime.datetime(2000, 1, 20, 4, 0),
#  datetime.datetime(2000, 1, 20, 5, 0),
#  datetime.datetime(2000, 1, 20, 6, 0),
#  datetime.datetime(2000, 1, 20, 7, 0),
#  datetime.datetime(2000, 1, 20, 8, 0),
#  datetime.datetime(2000, 1, 20, 9, 0),
#  datetime.datetime(2000, 1, 20, 10, 0),
#  datetime.datetime(2000, 1, 20, 11, 0),
#  datetime.datetime(2000, 1, 20, 12, 0),
#  datetime.datetime(2000, 1, 20, 13, 0),
#  datetime.datetime(2000, 1, 20, 14, 0),
#  datetime.datetime(2000, 1, 20, 15, 0),
#  datetime.datetime(2000, 1, 20, 16, 0),
#  datetime.datetime(2000, 1, 20, 17, 0),
#  datetime.datetime(2000, 1, 20, 18, 0),
#  datetime.datetime(2000, 1, 20, 19, 0),
#  datetime.datetime(2000, 1, 20, 20, 0),
#  datetime.datetime(2000, 1, 20, 21, 0),
#  datetime.datetime(2000, 1, 20, 22, 0),
#  datetime.datetime(2000, 1, 20, 23, 0),
#  datetime.datetime(2000, 1, 21, 0, 0),
#  datetime.datetime(2000, 1, 21, 1, 0),
#  datetime.datetime(2000, 1, 21, 2, 0),
#  datetime.datetime(2000, 1, 21, 3, 0),
#  datetime.datetime(2000, 1, 21, 4, 0),
#  datetime.datetime(2000, 1, 21, 5, 0),
#  datetime.datetime(2000, 1, 21, 6, 0),
#  datetime.datetime(2000, 1, 21, 7, 0),
#  datetime.datetime(2000, 1, 21, 8, 0),
#  datetime.datetime(2000, 1, 21, 9, 0),
#  datetime.datetime(2000, 1, 21, 10, 0),
#  datetime.datetime(2000, 1, 21, 11, 0),
#  datetime.datetime(2000, 1, 21, 12, 0),
#  datetime.datetime(2000, 1, 21, 13, 0),
#  datetime.datetime(2000, 1, 21, 14, 0),
#  datetime.datetime(2000, 1, 21, 15, 0),
#  datetime.datetime(2000, 1, 21, 16, 0),
#  datetime.datetime(2000, 1, 21, 17, 0),
#  datetime.datetime(2000, 1, 21, 18, 0),
#  datetime.datetime(2000, 1, 21, 19, 0),
#  datetime.datetime(2000, 1, 21, 20, 0),
#  datetime.datetime(2000, 1, 21, 21, 0),
#  datetime.datetime(2000, 1, 21, 22, 0),
#  datetime.datetime(2000, 1, 21, 23, 0),
#  datetime.datetime(2000, 1, 22, 0, 0),
#  datetime.datetime(2000, 1, 22, 1, 0),
#  datetime.datetime(2000, 1, 22, 2, 0),
#  datetime.datetime(2000, 1, 22, 3, 0),
#  datetime.datetime(2000, 1, 22, 4, 0),
#  datetime.datetime(2000, 1, 22, 5, 0),
#  datetime.datetime(2000, 1, 22, 6, 0),
#  datetime.datetime(2000, 1, 22, 7, 0),
#  datetime.datetime(2000, 1, 22, 8, 0),
#  datetime.datetime(2000, 1, 22, 9, 0),
#  datetime.datetime(2000, 1, 22, 10, 0),
#  datetime.datetime(2000, 1, 22, 11, 0),
#  datetime.datetime(2000, 1, 22, 12, 0),
#  datetime.datetime(2000, 1, 22, 13, 0),
#  datetime.datetime(2000, 1, 22, 14, 0),
#  datetime.datetime(2000, 1, 22, 15, 0),
#  datetime.datetime(2000, 1, 22, 16, 0),
#  datetime.datetime(2000, 1, 22, 17, 0),
#  datetime.datetime(2000, 1, 22, 18, 0),
#  datetime.datetime(2000, 1, 22, 19, 0),
#  datetime.datetime(2000, 1, 22, 20, 0),
#  datetime.datetime(2000, 1, 22, 21, 0),
#  datetime.datetime(2000, 1, 22, 22, 0),
#  datetime.datetime(2000, 1, 22, 23, 0),
#  datetime.datetime(2000, 1, 23, 0, 0),
#  datetime.datetime(2000, 1, 23, 1, 0),
#  datetime.datetime(2000, 1, 23, 2, 0),
#  datetime.datetime(2000, 1, 23, 3, 0),
#  datetime.datetime(2000, 1, 23, 4, 0),
#  datetime.datetime(2000, 1, 23, 5, 0),
#  datetime.datetime(2000, 1, 23, 6, 0),
#  datetime.datetime(2000, 1, 23, 7, 0),
#  datetime.datetime(2000, 1, 23, 8, 0),
#  datetime.datetime(2000, 1, 23, 9, 0),
#  datetime.datetime(2000, 1, 23, 10, 0),
#  datetime.datetime(2000, 1, 23, 11, 0),
#  datetime.datetime(2000, 1, 23, 12, 0),
#  datetime.datetime(2000, 1, 23, 13, 0),
#  datetime.datetime(2000, 1, 23, 14, 0),
#  datetime.datetime(2000, 1, 23, 15, 0),
#  datetime.datetime(2000, 1, 23, 16, 0),
#  datetime.datetime(2000, 1, 23, 17, 0),
#  datetime.datetime(2000, 1, 23, 18, 0),
#  datetime.datetime(2000, 1, 23, 19, 0),
#  datetime.datetime(2000, 1, 23, 20, 0),
#  datetime.datetime(2000, 1, 23, 21, 0),
#  datetime.datetime(2000, 1, 23, 22, 0),
#  datetime.datetime(2000, 1, 23, 23, 0),
#  datetime.datetime(2000, 1, 24, 0, 0),
#  datetime.datetime(2000, 1, 24, 1, 0),
#  datetime.datetime(2000, 1, 24, 2, 0),
#  datetime.datetime(2000, 1, 24, 3, 0),
#  datetime.datetime(2000, 1, 24, 4, 0),
#  datetime.datetime(2000, 1, 24, 5, 0),
#  datetime.datetime(2000, 1, 24, 6, 0),
#  datetime.datetime(2000, 1, 24, 7, 0),
#  datetime.datetime(2000, 1, 24, 8, 0),
#  datetime.datetime(2000, 1, 24, 9, 0),
#  datetime.datetime(2000, 1, 24, 10, 0),
#  datetime.datetime(2000, 1, 24, 11, 0),
#  datetime.datetime(2000, 1, 24, 12, 0),
#  datetime.datetime(2000, 1, 24, 13, 0),
#  datetime.datetime(2000, 1, 24, 14, 0),
#  datetime.datetime(2000, 1, 24, 15, 0),
#  datetime.datetime(2000, 1, 24, 16, 0),
#  datetime.datetime(2000, 1, 24, 17, 0),
#  datetime.datetime(2000, 1, 24, 18, 0),
#  datetime.datetime(2000, 1, 24, 19, 0),
#  datetime.datetime(2000, 1, 24, 20, 0),
#  datetime.datetime(2000, 1, 24, 21, 0),
#  datetime.datetime(2000, 1, 24, 22, 0),
#  datetime.datetime(2000, 1, 24, 23, 0),
#  datetime.datetime(2000, 1, 25, 0, 0),
#  datetime.datetime(2000, 1, 25, 1, 0),
#  datetime.datetime(2000, 1, 25, 2, 0),
#  datetime.datetime(2000, 1, 25, 3, 0),
#  datetime.datetime(2000, 1, 25, 4, 0),
#  datetime.datetime(2000, 1, 25, 5, 0),
#  datetime.datetime(2000, 1, 25, 6, 0),
#  datetime.datetime(2000, 1, 25, 7, 0),
#  datetime.datetime(2000, 1, 25, 8, 0),
#  datetime.datetime(2000, 1, 25, 9, 0),
#  datetime.datetime(2000, 1, 25, 10, 0),
#  datetime.datetime(2000, 1, 25, 11, 0),
#  datetime.datetime(2000, 1, 25, 12, 0),
#  datetime.datetime(2000, 1, 25, 13, 0),
#  datetime.datetime(2000, 1, 25, 14, 0),
#  datetime.datetime(2000, 1, 25, 15, 0),
#  datetime.datetime(2000, 1, 25, 16, 0),
#  datetime.datetime(2000, 1, 25, 17, 0),
#  datetime.datetime(2000, 1, 25, 18, 0),
#  datetime.datetime(2000, 1, 25, 19, 0),
#  datetime.datetime(2000, 1, 25, 20, 0),
#  datetime.datetime(2000, 1, 25, 21, 0),
#  datetime.datetime(2000, 1, 25, 22, 0),
#  datetime.datetime(2000, 1, 25, 23, 0),
#  datetime.datetime(2000, 1, 26, 0, 0),
#  datetime.datetime(2000, 1, 26, 1, 0),
#  datetime.datetime(2000, 1, 26, 2, 0),
#  datetime.datetime(2000, 1, 26, 3, 0),
#  datetime.datetime(2000, 1, 26, 4, 0),
#  datetime.datetime(2000, 1, 26, 5, 0),
#  datetime.datetime(2000, 1, 26, 6, 0),
#  datetime.datetime(2000, 1, 26, 7, 0),
#  datetime.datetime(2000, 1, 26, 8, 0),
#  datetime.datetime(2000, 1, 26, 9, 0),
#  datetime.datetime(2000, 1, 26, 10, 0),
#  datetime.datetime(2000, 1, 26, 11, 0),
#  datetime.datetime(2000, 1, 26, 12, 0),
#  datetime.datetime(2000, 1, 26, 13, 0),
#  datetime.datetime(2000, 1, 26, 14, 0),
#  datetime.datetime(2000, 1, 26, 15, 0),
#  datetime.datetime(2000, 1, 26, 16, 0),
#  datetime.datetime(2000, 1, 26, 17, 0),
#  datetime.datetime(2000, 1, 26, 18, 0),
#  datetime.datetime(2000, 1, 26, 19, 0),
#  datetime.datetime(2000, 1, 26, 20, 0),
#  datetime.datetime(2000, 1, 26, 21, 0),
#  datetime.datetime(2000, 1, 26, 22, 0),
#  datetime.datetime(2000, 1, 26, 23, 0),
#  datetime.datetime(2000, 1, 27, 0, 0),
#  datetime.datetime(2000, 1, 27, 1, 0),
#  datetime.datetime(2000, 1, 27, 2, 0),
#  datetime.datetime(2000, 1, 27, 3, 0),
#  datetime.datetime(2000, 1, 27, 4, 0),
#  datetime.datetime(2000, 1, 27, 5, 0),
#  datetime.datetime(2000, 1, 27, 6, 0),
#  datetime.datetime(2000, 1, 27, 7, 0),
#  datetime.datetime(2000, 1, 27, 8, 0),
#  datetime.datetime(2000, 1, 27, 9, 0),
#  datetime.datetime(2000, 1, 27, 10, 0),
#  datetime.datetime(2000, 1, 27, 11, 0),
#  datetime.datetime(2000, 1, 27, 12, 0),
#  datetime.datetime(2000, 1, 27, 13, 0),
#  datetime.datetime(2000, 1, 27, 14, 0),
#  datetime.datetime(2000, 1, 27, 15, 0),
#  datetime.datetime(2000, 1, 27, 16, 0),
#  datetime.datetime(2000, 1, 27, 17, 0),
#  datetime.datetime(2000, 1, 27, 18, 0),
#  datetime.datetime(2000, 1, 27, 19, 0),
#  datetime.datetime(2000, 1, 27, 20, 0),
#  datetime.datetime(2000, 1, 27, 21, 0),
#  datetime.datetime(2000, 1, 27, 22, 0),
#  datetime.datetime(2000, 1, 27, 23, 0),
#  datetime.datetime(2000, 1, 28, 0, 0),
#  datetime.datetime(2000, 1, 28, 1, 0),
#  datetime.datetime(2000, 1, 28, 2, 0),
#  datetime.datetime(2000, 1, 28, 3, 0),
#  datetime.datetime(2000, 1, 28, 4, 0),
#  datetime.datetime(2000, 1, 28, 5, 0),
#  datetime.datetime(2000, 1, 28, 6, 0),
#  datetime.datetime(2000, 1, 28, 7, 0),
#  datetime.datetime(2000, 1, 28, 8, 0),
#  datetime.datetime(2000, 1, 28, 9, 0),
#  datetime.datetime(2000, 1, 28, 10, 0),
#  datetime.datetime(2000, 1, 28, 11, 0),
#  datetime.datetime(2000, 1, 28, 12, 0),
#  datetime.datetime(2000, 1, 28, 13, 0),
#  datetime.datetime(2000, 1, 28, 14, 0),
#  datetime.datetime(2000, 1, 28, 15, 0),
#  datetime.datetime(2000, 1, 28, 16, 0),
#  datetime.datetime(2000, 1, 28, 17, 0),
#  datetime.datetime(2000, 1, 28, 18, 0),
#  datetime.datetime(2000, 1, 28, 19, 0),
#  datetime.datetime(2000, 1, 28, 20, 0),
#  datetime.datetime(2000, 1, 28, 21, 0),
#  datetime.datetime(2000, 1, 28, 22, 0),
#  datetime.datetime(2000, 1, 28, 23, 0),
#  datetime.datetime(2000, 1, 29, 0, 0),
#  datetime.datetime(2000, 1, 29, 1, 0),
#  datetime.datetime(2000, 1, 29, 2, 0),
#  datetime.datetime(2000, 1, 29, 3, 0),
#  datetime.datetime(2000, 1, 29, 4, 0),
#  datetime.datetime(2000, 1, 29, 5, 0),
#  datetime.datetime(2000, 1, 29, 6, 0),
#  datetime.datetime(2000, 1, 29, 7, 0),
#  datetime.datetime(2000, 1, 29, 8, 0),
#  datetime.datetime(2000, 1, 29, 9, 0),
#  datetime.datetime(2000, 1, 29, 10, 0),
#  datetime.datetime(2000, 1, 29, 11, 0),
#  datetime.datetime(2000, 1, 29, 12, 0),
#  datetime.datetime(2000, 1, 29, 13, 0),
#  datetime.datetime(2000, 1, 29, 14, 0),
#  datetime.datetime(2000, 1, 29, 15, 0),
#  datetime.datetime(2000, 1, 29, 16, 0),
#  datetime.datetime(2000, 1, 29, 17, 0),
#  datetime.datetime(2000, 1, 29, 18, 0),
#  datetime.datetime(2000, 1, 29, 19, 0),
#  datetime.datetime(2000, 1, 29, 20, 0),
#  datetime.datetime(2000, 1, 29, 21, 0),
#  datetime.datetime(2000, 1, 29, 22, 0),
#  datetime.datetime(2000, 1, 29, 23, 0),
#  datetime.datetime(2000, 1, 30, 0, 0),
#  datetime.datetime(2000, 1, 30, 1, 0),
#  datetime.datetime(2000, 1, 30, 2, 0),
#  datetime.datetime(2000, 1, 30, 3, 0),
#  datetime.datetime(2000, 1, 30, 4, 0),
#  datetime.datetime(2000, 1, 30, 5, 0),
#  datetime.datetime(2000, 1, 30, 6, 0),
#  datetime.datetime(2000, 1, 30, 7, 0),
#  datetime.datetime(2000, 1, 30, 8, 0),
#  datetime.datetime(2000, 1, 30, 9, 0),
#  datetime.datetime(2000, 1, 30, 10, 0),
#  datetime.datetime(2000, 1, 30, 11, 0),
#  datetime.datetime(2000, 1, 30, 12, 0),
#  datetime.datetime(2000, 1, 30, 13, 0),
#  datetime.datetime(2000, 1, 30, 14, 0),
#  datetime.datetime(2000, 1, 30, 15, 0),
#  datetime.datetime(2000, 1, 30, 16, 0),
#  datetime.datetime(2000, 1, 30, 17, 0),
#  datetime.datetime(2000, 1, 30, 18, 0),
#  datetime.datetime(2000, 1, 30, 19, 0),
#  datetime.datetime(2000, 1, 30, 20, 0),
#  datetime.datetime(2000, 1, 30, 21, 0),
#  datetime.datetime(2000, 1, 30, 22, 0),
#  datetime.datetime(2000, 1, 30, 23, 0),
#  datetime.datetime(2000, 1, 31, 0, 0),
#  datetime.datetime(2000, 1, 31, 1, 0),
#  datetime.datetime(2000, 1, 31, 2, 0),
#  datetime.datetime(2000, 1, 31, 3, 0),
#  datetime.datetime(2000, 1, 31, 4, 0),
#  datetime.datetime(2000, 1, 31, 5, 0),
#  datetime.datetime(2000, 1, 31, 6, 0),
#  datetime.datetime(2000, 1, 31, 7, 0),
#  datetime.datetime(2000, 1, 31, 8, 0),
#  datetime.datetime(2000, 1, 31, 9, 0),
#  datetime.datetime(2000, 1, 31, 10, 0),
#  datetime.datetime(2000, 1, 31, 11, 0),
#  datetime.datetime(2000, 1, 31, 12, 0),
#  datetime.datetime(2000, 1, 31, 13, 0),
#  datetime.datetime(2000, 1, 31, 14, 0),
#  datetime.datetime(2000, 1, 31, 15, 0),
#  datetime.datetime(2000, 1, 31, 16, 0),
#  datetime.datetime(2000, 1, 31, 17, 0),
#  datetime.datetime(2000, 1, 31, 18, 0),
#  datetime.datetime(2000, 1, 31, 19, 0),
#  datetime.datetime(2000, 1, 31, 20, 0),
#  datetime.datetime(2000, 1, 31, 21, 0),
#  datetime.datetime(2000, 1, 31, 22, 0),
#  datetime.datetime(2000, 1, 31, 23, 0),
#  datetime.datetime(2000, 2, 1, 0, 0),
#  datetime.datetime(2000, 2, 1, 1, 0),
#  datetime.datetime(2000, 2, 1, 2, 0),
#  datetime.datetime(2000, 2, 1, 3, 0),
#  datetime.datetime(2000, 2, 1, 4, 0),
#  datetime.datetime(2000, 2, 1, 5, 0),
#  datetime.datetime(2000, 2, 1, 6, 0),
#  datetime.datetime(2000, 2, 1, 7, 0),
#  datetime.datetime(2000, 2, 1, 8, 0),
#  datetime.datetime(2000, 2, 1, 9, 0),
#  datetime.datetime(2000, 2, 1, 10, 0),
#  datetime.datetime(2000, 2, 1, 11, 0),
#  datetime.datetime(2000, 2, 1, 12, 0),
#  datetime.datetime(2000, 2, 1, 13, 0),
#  datetime.datetime(2000, 2, 1, 14, 0),
#  datetime.datetime(2000, 2, 1, 15, 0),
#  datetime.datetime(2000, 2, 1, 16, 0),
#  datetime.datetime(2000, 2, 1, 17, 0),
#  datetime.datetime(2000, 2, 1, 18, 0),
#  datetime.datetime(2000, 2, 1, 19, 0),
#  datetime.datetime(2000, 2, 1, 20, 0),
#  datetime.datetime(2000, 2, 1, 21, 0),
#  datetime.datetime(2000, 2, 1, 22, 0),
#  datetime.datetime(2000, 2, 1, 23, 0),
#  datetime.datetime(2000, 2, 2, 0, 0),
#  datetime.datetime(2000, 2, 2, 1, 0),
#  datetime.datetime(2000, 2, 2, 2, 0),
#  datetime.datetime(2000, 2, 2, 3, 0),
#  datetime.datetime(2000, 2, 2, 4, 0),
#  datetime.datetime(2000, 2, 2, 5, 0),
#  datetime.datetime(2000, 2, 2, 6, 0),
#  datetime.datetime(2000, 2, 2, 7, 0),
#  datetime.datetime(2000, 2, 2, 8, 0),
#  datetime.datetime(2000, 2, 2, 9, 0),
#  datetime.datetime(2000, 2, 2, 10, 0),
#  datetime.datetime(2000, 2, 2, 11, 0),
#  datetime.datetime(2000, 2, 2, 12, 0),
#  datetime.datetime(2000, 2, 2, 13, 0),
#  datetime.datetime(2000, 2, 2, 14, 0),
#  datetime.datetime(2000, 2, 2, 15, 0),
#  datetime.datetime(2000, 2, 2, 16, 0),
#  datetime.datetime(2000, 2, 2, 17, 0),
#  datetime.datetime(2000, 2, 2, 18, 0),
#  datetime.datetime(2000, 2, 2, 19, 0),
#  datetime.datetime(2000, 2, 2, 20, 0),
#  datetime.datetime(2000, 2, 2, 21, 0),
#  datetime.datetime(2000, 2, 2, 22, 0),
#  datetime.datetime(2000, 2, 2, 23, 0),
#  datetime.datetime(2000, 2, 3, 0, 0),
#  datetime.datetime(2000, 2, 3, 1, 0),
#  datetime.datetime(2000, 2, 3, 2, 0),
#  datetime.datetime(2000, 2, 3, 3, 0),
#  datetime.datetime(2000, 2, 3, 4, 0),
#  datetime.datetime(2000, 2, 3, 5, 0),
#  datetime.datetime(2000, 2, 3, 6, 0),
#  datetime.datetime(2000, 2, 3, 7, 0),
#  datetime.datetime(2000, 2, 3, 8, 0),
#  datetime.datetime(2000, 2, 3, 9, 0),
#  datetime.datetime(2000, 2, 3, 10, 0),
#  datetime.datetime(2000, 2, 3, 11, 0),
#  datetime.datetime(2000, 2, 3, 12, 0),
#  datetime.datetime(2000, 2, 3, 13, 0),
#  datetime.datetime(2000, 2, 3, 14, 0),
#  datetime.datetime(2000, 2, 3, 15, 0),
#  datetime.datetime(2000, 2, 3, 16, 0),
#  datetime.datetime(2000, 2, 3, 17, 0),
#  datetime.datetime(2000, 2, 3, 18, 0),
#  datetime.datetime(2000, 2, 3, 19, 0),
#  datetime.datetime(2000, 2, 3, 20, 0),
#  datetime.datetime(2000, 2, 3, 21, 0),
#  datetime.datetime(2000, 2, 3, 22, 0),
#  datetime.datetime(2000, 2, 3, 23, 0),
#  datetime.datetime(2000, 2, 4, 0, 0),
#  datetime.datetime(2000, 2, 4, 1, 0),
#  datetime.datetime(2000, 2, 4, 2, 0),
#  datetime.datetime(2000, 2, 4, 3, 0),
#  datetime.datetime(2000, 2, 4, 4, 0),
#  datetime.datetime(2000, 2, 4, 5, 0),
#  datetime.datetime(2000, 2, 4, 6, 0),
#  datetime.datetime(2000, 2, 4, 7, 0),
#  datetime.datetime(2000, 2, 4, 8, 0),
#  datetime.datetime(2000, 2, 4, 9, 0),
#  datetime.datetime(2000, 2, 4, 10, 0),
#  datetime.datetime(2000, 2, 4, 11, 0),
#  datetime.datetime(2000, 2, 4, 12, 0),
#  datetime.datetime(2000, 2, 4, 13, 0),
#  datetime.datetime(2000, 2, 4, 14, 0),
#  datetime.datetime(2000, 2, 4, 15, 0),
#  datetime.datetime(2000, 2, 4, 16, 0),
#  datetime.datetime(2000, 2, 4, 17, 0),
#  datetime.datetime(2000, 2, 4, 18, 0),
#  datetime.datetime(2000, 2, 4, 19, 0),
#  datetime.datetime(2000, 2, 4, 20, 0),
#  datetime.datetime(2000, 2, 4, 21, 0),
#  datetime.datetime(2000, 2, 4, 22, 0),
#  datetime.datetime(2000, 2, 4, 23, 0),
#  datetime.datetime(2000, 2, 5, 0, 0),
#  datetime.datetime(2000, 2, 5, 1, 0),
#  datetime.datetime(2000, 2, 5, 2, 0),
#  datetime.datetime(2000, 2, 5, 3, 0),
#  datetime.datetime(2000, 2, 5, 4, 0),
#  datetime.datetime(2000, 2, 5, 5, 0),
#  datetime.datetime(2000, 2, 5, 6, 0),
#  datetime.datetime(2000, 2, 5, 7, 0),
#  datetime.datetime(2000, 2, 5, 8, 0),
#  datetime.datetime(2000, 2, 5, 9, 0),
#  datetime.datetime(2000, 2, 5, 10, 0),
#  datetime.datetime(2000, 2, 5, 11, 0),
#  datetime.datetime(2000, 2, 5, 12, 0),
#  datetime.datetime(2000, 2, 5, 13, 0),
#  datetime.datetime(2000, 2, 5, 14, 0),
#  datetime.datetime(2000, 2, 5, 15, 0),
#  datetime.datetime(2000, 2, 5, 16, 0),
#  datetime.datetime(2000, 2, 5, 17, 0),
#  datetime.datetime(2000, 2, 5, 18, 0),
#  datetime.datetime(2000, 2, 5, 19, 0),
#  datetime.datetime(2000, 2, 5, 20, 0),
#  datetime.datetime(2000, 2, 5, 21, 0),
#  datetime.datetime(2000, 2, 5, 22, 0),
#  datetime.datetime(2000, 2, 5, 23, 0),
#  datetime.datetime(2000, 2, 6, 0, 0),
#  datetime.datetime(2000, 2, 6, 1, 0),
#  datetime.datetime(2000, 2, 6, 2, 0),
#  datetime.datetime(2000, 2, 6, 3, 0),
#  datetime.datetime(2000, 2, 6, 4, 0),
#  datetime.datetime(2000, 2, 6, 5, 0),
#  datetime.datetime(2000, 2, 6, 6, 0),
#  datetime.datetime(2000, 2, 6, 7, 0),
#  datetime.datetime(2000, 2, 6, 8, 0),
#  datetime.datetime(2000, 2, 6, 9, 0),
#  datetime.datetime(2000, 2, 6, 10, 0),
#  datetime.datetime(2000, 2, 6, 11, 0),
#  datetime.datetime(2000, 2, 6, 12, 0),
#  datetime.datetime(2000, 2, 6, 13, 0),
#  datetime.datetime(2000, 2, 6, 14, 0),
#  datetime.datetime(2000, 2, 6, 15, 0),
#  datetime.datetime(2000, 2, 6, 16, 0),
#  datetime.datetime(2000, 2, 6, 17, 0),
#  datetime.datetime(2000, 2, 6, 18, 0),
#  datetime.datetime(2000, 2, 6, 19, 0),
#  datetime.datetime(2000, 2, 6, 20, 0),
#  datetime.datetime(2000, 2, 6, 21, 0),
#  datetime.datetime(2000, 2, 6, 22, 0),
#  datetime.datetime(2000, 2, 6, 23, 0),
#  datetime.datetime(2000, 2, 7, 0, 0),
#  datetime.datetime(2000, 2, 7, 1, 0),
#  datetime.datetime(2000, 2, 7, 2, 0),
#  datetime.datetime(2000, 2, 7, 3, 0),
#  datetime.datetime(2000, 2, 7, 4, 0),
#  datetime.datetime(2000, 2, 7, 5, 0),
#  datetime.datetime(2000, 2, 7, 6, 0),
#  datetime.datetime(2000, 2, 7, 7, 0),
#  datetime.datetime(2000, 2, 7, 8, 0),
#  datetime.datetime(2000, 2, 7, 9, 0),
#  datetime.datetime(2000, 2, 7, 10, 0),
#  datetime.datetime(2000, 2, 7, 11, 0),
#  datetime.datetime(2000, 2, 7, 12, 0),
#  datetime.datetime(2000, 2, 7, 13, 0),
#  datetime.datetime(2000, 2, 7, 14, 0),
#  datetime.datetime(2000, 2, 7, 15, 0),
#  datetime.datetime(2000, 2, 7, 16, 0),
#  datetime.datetime(2000, 2, 7, 17, 0),
#  datetime.datetime(2000, 2, 7, 18, 0),
#  datetime.datetime(2000, 2, 7, 19, 0),
#  datetime.datetime(2000, 2, 7, 20, 0),
#  datetime.datetime(2000, 2, 7, 21, 0),
#  datetime.datetime(2000, 2, 7, 22, 0),
#  datetime.datetime(2000, 2, 7, 23, 0),
#  datetime.datetime(2000, 2, 8, 0, 0),
#  datetime.datetime(2000, 2, 8, 1, 0),
#  datetime.datetime(2000, 2, 8, 2, 0),
#  datetime.datetime(2000, 2, 8, 3, 0),
#  datetime.datetime(2000, 2, 8, 4, 0),
#  datetime.datetime(2000, 2, 8, 5, 0),
#  datetime.datetime(2000, 2, 8, 6, 0),
#  datetime.datetime(2000, 2, 8, 7, 0),
#  datetime.datetime(2000, 2, 8, 8, 0),
#  datetime.datetime(2000, 2, 8, 9, 0),
#  datetime.datetime(2000, 2, 8, 10, 0),
#  datetime.datetime(2000, 2, 8, 11, 0),
#  datetime.datetime(2000, 2, 8, 12, 0),
#  datetime.datetime(2000, 2, 8, 13, 0),
#  datetime.datetime(2000, 2, 8, 14, 0),
#  datetime.datetime(2000, 2, 8, 15, 0),
#  datetime.datetime(2000, 2, 8, 16, 0),
#  datetime.datetime(2000, 2, 8, 17, 0),
#  datetime.datetime(2000, 2, 8, 18, 0),
#  datetime.datetime(2000, 2, 8, 19, 0),
#  datetime.datetime(2000, 2, 8, 20, 0),
#  datetime.datetime(2000, 2, 8, 21, 0),
#  datetime.datetime(2000, 2, 8, 22, 0),
#  datetime.datetime(2000, 2, 8, 23, 0),
#  datetime.datetime(2000, 2, 9, 0, 0),
#  datetime.datetime(2000, 2, 9, 1, 0),
#  datetime.datetime(2000, 2, 9, 2, 0),
#  datetime.datetime(2000, 2, 9, 3, 0),
#  datetime.datetime(2000, 2, 9, 4, 0),
#  datetime.datetime(2000, 2, 9, 5, 0),
#  datetime.datetime(2000, 2, 9, 6, 0),
#  datetime.datetime(2000, 2, 9, 7, 0),
#  datetime.datetime(2000, 2, 9, 8, 0),
#  datetime.datetime(2000, 2, 9, 9, 0),
#  datetime.datetime(2000, 2, 9, 10, 0),
#  datetime.datetime(2000, 2, 9, 11, 0),
#  datetime.datetime(2000, 2, 9, 12, 0),
#  datetime.datetime(2000, 2, 9, 13, 0),
#  datetime.datetime(2000, 2, 9, 14, 0),
#  datetime.datetime(2000, 2, 9, 15, 0),
#  datetime.datetime(2000, 2, 9, 16, 0),
#  datetime.datetime(2000, 2, 9, 17, 0),
#  datetime.datetime(2000, 2, 9, 18, 0),
#  datetime.datetime(2000, 2, 9, 19, 0),
#  datetime.datetime(2000, 2, 9, 20, 0),
#  datetime.datetime(2000, 2, 9, 21, 0),
#  datetime.datetime(2000, 2, 9, 22, 0),
#  datetime.datetime(2000, 2, 9, 23, 0),
#  datetime.datetime(2000, 2, 10, 0, 0),
#  datetime.datetime(2000, 2, 10, 1, 0),
#  datetime.datetime(2000, 2, 10, 2, 0),
#  datetime.datetime(2000, 2, 10, 3, 0),
#  datetime.datetime(2000, 2, 10, 4, 0),
#  datetime.datetime(2000, 2, 10, 5, 0),
#  datetime.datetime(2000, 2, 10, 6, 0),
#  datetime.datetime(2000, 2, 10, 7, 0),
#  datetime.datetime(2000, 2, 10, 8, 0),
#  datetime.datetime(2000, 2, 10, 9, 0),
#  datetime.datetime(2000, 2, 10, 10, 0),
#  datetime.datetime(2000, 2, 10, 11, 0),
#  datetime.datetime(2000, 2, 10, 12, 0),
#  datetime.datetime(2000, 2, 10, 13, 0),
#  datetime.datetime(2000, 2, 10, 14, 0),
#  datetime.datetime(2000, 2, 10, 15, 0),
#  datetime.datetime(2000, 2, 10, 16, 0),
#  datetime.datetime(2000, 2, 10, 17, 0),
#  datetime.datetime(2000, 2, 10, 18, 0),
#  datetime.datetime(2000, 2, 10, 19, 0),
#  datetime.datetime(2000, 2, 10, 20, 0),
#  datetime.datetime(2000, 2, 10, 21, 0),
#  datetime.datetime(2000, 2, 10, 22, 0),
#  datetime.datetime(2000, 2, 10, 23, 0),
#  datetime.datetime(2000, 2, 11, 0, 0),
#  datetime.datetime(2000, 2, 11, 1, 0),
#  datetime.datetime(2000, 2, 11, 2, 0),
#  datetime.datetime(2000, 2, 11, 3, 0),
#  datetime.datetime(2000, 2, 11, 4, 0),
#  datetime.datetime(2000, 2, 11, 5, 0),
#  datetime.datetime(2000, 2, 11, 6, 0),
#  datetime.datetime(2000, 2, 11, 7, 0),
#  datetime.datetime(2000, 2, 11, 8, 0),
#  datetime.datetime(2000, 2, 11, 9, 0),
#  datetime.datetime(2000, 2, 11, 10, 0),
#  datetime.datetime(2000, 2, 11, 11, 0),
#  datetime.datetime(2000, 2, 11, 12, 0),
#  datetime.datetime(2000, 2, 11, 13, 0),
#  datetime.datetime(2000, 2, 11, 14, 0),
#  datetime.datetime(2000, 2, 11, 15, 0),
#  ...]
