# %%
import xarray as xr
from cartopy import config
import cartopy.crs as ccrs
import cartopy.mpl.ticker as cticker
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error
from scipy.optimize import minimize
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import numpy as np
import datetime
import glob 
import pandas as pd
import seaborn as sns
import geopandas as gpd
sns.set()

# %%
# Specifying paths and list all filenames
path = '/Users/jacobqs/Downloads/shyft-data-master/netcdf/orchestration-testdata/'

cell_data_f = glob.glob(path + 'cell_data.nc')
dis_f = glob.glob(path + 'discharge.nc')
precip_f = glob.glob(path + 'precipitation.nc')
rad_f = glob.glob(path + 'radiation.nc')
rel_hum_f = glob.glob(path + 'relative_humidity.nc')
temp_f = glob.glob(path + 'temperature.nc')
wind_f = glob.glob(path + 'wind_speed.nc')

# Importing multiple NetCDF files

cell_data = xr.open_mfdataset(cell_data_f) #Surface temperature (average, 24 hour values) [K]
dis = xr.open_mfdataset(dis_f) #Surface temperature (max, 24 hour values) [K]
precip = xr.open_mfdataset(precip_f) #Surface temperature (min, 24 hour values) [K]
rad = xr.open_mfdataset(rad_f) # Shortwave radiation [W m-2]
rel_hum = xr.open_mfdataset(rel_hum_f) # Precipitation (sum of snowfall and rainfall) [kg m-2 s-1]
temp = xr.open_mfdataset(temp_f) # Wind [m s-1]
wind = xr.open_mfdataset(wind_f) # Near-surface relative humidity [%]

# %%
temp
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 8760, station: 11)
# Coordinates:
#   * time         (time) datetime64[ns] 2013-09-01 ... 2014-08-31T23:00:00
#     x            (station) float64 dask.array<chunksize=(11,), meta=np.ndarray>
#     y            (station) float64 dask.array<chunksize=(11,), meta=np.ndarray>
#     z            (station) float64 dask.array<chunksize=(11,), meta=np.ndarray>
# Dimensions without coordinates: station
# Data variables:
#     series_name  (station) object dask.array<chunksize=(11,), meta=np.ndarray>
#     crs          int32 ...
#     temperature  (time, station) float64 dask.array<chunksize=(8760, 11), meta=np.ndarray>
