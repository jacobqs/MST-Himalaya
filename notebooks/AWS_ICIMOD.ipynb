# %%
import os
import pandas as pd

# %%
home_dir = os.getenv('HOME')
yala_glacier_path = home_dir + '/Documents/MST Himalaya/MST-Himalaya/shyft_workspace_copy/shyft_workspace/shyft-data/netcdf/orchestration-testdata/ AWS Yala Glacier/data/AWSYalaGlacier.csv'

# %%
df = pd.read_csv(yala_glacier_path)

# %%
df.describe()
# Out:
#                TAIR            RH         TCNR4          KINC          KOUT  \
# count  29988.000000  29988.000000  29985.000000  29985.000000  29985.000000
# mean      -4.425942     64.026315     -7.721924    219.402300    145.828607
# std        5.989414     33.558981      8.866891    319.193435    222.494340
# min      -23.400000      1.262833    -51.510000      0.000000      0.000000
# 25%       -8.840417     29.143750    -14.090588      0.000000      0.000000
# 50%       -3.500000     75.600000     -5.130000      9.398424      8.720000
# 75%        0.810000     98.067500      0.085432    378.764650    243.310800
# max       17.910000    100.000000     12.320000   1449.969500   1277.920000
#
#                LINC          LOUT         WSPD1         WSPD2       WINDDIR  \
# count  29985.000000  29985.000000  11218.000000  29145.000000  29147.000000
# mean     241.115852    281.710125      1.616129      1.874754    164.672723
# ...
